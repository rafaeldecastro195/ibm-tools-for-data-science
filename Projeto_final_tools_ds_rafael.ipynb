# %%
Criado em 09/02/2026
Versão 1.02

# %% [markdown]
# # Projeto final do curso Tools for Data Science da IBM na plataforma da Coursera
# #### Prática de Jupyter Notebooks, code cells e markdown

# %% [markdown]
# ## - *Exercício um:*
# ##### **Descrição:** pede-se para criar uma célula de markdown com o título do notebook.
# ##### **Minha resolução:**

# %% [markdown]
#  # Mostra de Ferramentas e Ecossostema de Ciência de Dados

# %% [markdown]
# #### Resolução do Exercício nove
# **Objetivos**
# - Listar algumas das linguagens de programação mais populares para cientistas de dados;
# - Listar algumas das bibliotecas mais populares para cientistas de dados;
# - Criar uma tabela que contém algumas das ferramentas mais usadas em Ciência de Dados;
# - Mostrar algumas expressões aritméticas básicas em Python.

# %% [markdown]
# ## - *Exercício dois:*
# ##### **Descrição:** pede-se para criar uma célula de markdown com uma introdução para o assunto.
# ##### **Minha resolução:**

# %% [markdown]
# Nesse notebook, algumas ferramentas de Ciência de Dados são descritas.

# %% [markdown]
# ## - *Exercício três:*
# ##### **Descrição:** pede-se para criar uma célula de markdown com uma ordenada com algumas das linguagens populares usadas por Cientistas de Dados.
# ##### **Minha resolução:**

# %% [markdown]
# Algumas das linguagens de programação mais populares entre Cientistas de Dados são:
#
# 1. Python
# 2. R
# 3. Julia
# 4. Scala
# 5. Java

# %% [markdown]
# ## - *Exercício quatro:*
# ##### **Descrição:** pede-se para criar uma célula de markdown com uma ordenada com algumas das bibliotecas populares usadas por Cientistas de Dados.
# ##### **Minha resolução:**

# %% [markdown]
# Algumas das biliotecas mais usadas por Cientistas de Dados são:
# 1. Pandas
# 2. Numpy
# 3. Plotly
# 4. Matplotlib
# 5. Seaborn
# 6. Scikit Learn

# %% [markdown]
# ## - *Exercício cinco:*
# ##### **Descrição:** pede-se para criar uma célula de markdown com uma tabela de uma coluna sobre algumas ferramentas de Ciência de Dados, como IDEs e Toolkits.
# ##### **Minha resolução:**

# %% [markdown]
# Nessa coluna estão algumas ferramentas de Ciência de Dados:
#
# | Ferramenta de Ciência de Dados |
# | :---: |
# | Jupyter Lab |
# | Spyder |
# | Anaconda |
# | Visual Studio Code |

# %% [markdown]
# ## - *Exercício seis:*
# ##### **Descrição:** pede-se para criar uma célula de código com exemplos de algumas expressões aritméticas em Python.
# ##### **Minha resolução:**

# %%
# exemplos de expressões aritméticas básicas em Python

a = 3
b = 4

print(f'Expressões aritméticas básicas:\npara este exemplo, será levado em conta que a = {a} e b = {b}')
print(f'Soma: a + b = {a + b}')
print(f'Subtração: a - b = {a - b}')
print(f'Multiplicação: a * b = {a * b}')
print(f'Divisão (true division): a / b = {a / b}')
# Out:
# Expressões aritméticas básicas:
# para este exemplo, será levado em conta que a = 3 e b = 4
# Soma: a + b = 7
# Subtração: a - b = -1
# Multiplicação: a * b = 12
# Divisão (true division): a / b = 0.75

# %% [markdown]
# ## - *Exercício sete:*
# ##### **Descrição:** pede-se para criar uma célula de código com exemplos de uma expressão aritméticas simples de multiplicação e soma, com valores predefinidos, em Python.
# ##### **Minha resolução:**

# %%
# conta básica de multiplicação e adição com valores predefinidos
a = 3
b = 4
c = 5

expressao = (a * b) + c
print(expressao)
# Out:
# 17

# %% [markdown]
# ## - *Exercício oito:*
# ##### **Descrição:** pede-se para criar uma célula de código com cálculo de conversão minutos em horas, com valores predefinidos, em Python.
# ##### **Minha resolução:**

# %%
# Algoritmo de conversão de 200 minutos em horas
def conversao_minutos_horas(minutos):
    return minutos/60
minutos = 200
horas = conversao_minutos_horas(minutos)

print(f'{minutos} minutos correspondem a, aproximadamente, {horas:.2f} horas.')
# Out:
# 200 minutos correspondem a, aproximadamente, 3.33 horas.

# %% [markdown]
# ## - *Exercício nove:*
# ##### **Descrição:** pede-se para criar uma célula de markdown inserindo objetivos em uma lista não ordenada, logo acima do exercício dois.
# ##### **Minha resolução:**
# Marcado logo acima do exercício dois.

# %% [markdown]
# ## - *Exercício dez:*
# ##### **Descrição:** pede-se para criar uma célula de markdown inserindo o meu nome como o do autor deste notebook.
# ##### **Minha resolução:**

# %% [markdown]
# ## Autor:
# Rafael de Castro

# %% [markdown]
# # Conclusões
#
# Através do conteúdo estudado no curso [Tools for Data Science](https://www.coursera.org/learn/open-source-tools-for-data-science?specialization=ibm-data-science) e deste notebook, pratiquei:
# - Formatação em markdown para documentação;
# - Execução de operações básicas em Python;
# - Organização de informações sobre ferramentas populares para Ciência de Dados.
#
# Os conceitos aqui apresentados servirão como base para os próximos cursos da especialização [IBM Data Science](https://www.coursera.org/professional-certificates/ibm-data-science), oferecida pela IBM na Coursera.
